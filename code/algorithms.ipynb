# %% [markdown]
# # AI Algorithms
# > By Sayed Afnan Khazi(01JST21CB036), Venkat Bhaskar(01JST21CB049), G Rutvik(01JST21CB012), Sai Sujith(01JST21CB033)
# - This notebook showcases the implementation of Artificial Neural Networks, K-Nearest Neighbors, Decision Trees, Random Forest, Support Vector Machines, and Reinforcement Learning (Q-learning) on a financial dataset containing Alibaba's stock prices for the past many years.

# %% [markdown]
# ### Importing Libraries

# %%
# Install all the requirements
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: absl-py==2.1.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: appnope==0.1.4 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.1.4)
# Requirement already satisfied: asttokens==2.4.1 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (2.4.1)
# Requirement already satisfied: astunparse==1.6.3 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (1.6.3)
# Requirement already satisfied: certifi==2024.2.2 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (2024.2.2)
# Requirement already satisfied: charset-normalizer==3.3.2 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: comm==0.2.2 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (0.2.2)
# Requirement already satisfied: debugpy==1.8.1 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (1.8.1)
# Requirement already satisfied: decorator==5.1.1 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (5.1.1)
# Requirement already satisfied: executing==2.0.1 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: flatbuffers==24.3.25 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (24.3.25)
# Requirement already satisfied: gast==0.5.4 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (0.5.4)
# Requirement already satisfied: google-pasta==0.2.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: grpcio==1.64.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (1.64.0)
# Requirement already satisfied: h5py==3.11.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 15)) (3.11.0)
# Requirement already satisfied: idna==3.7 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 16)) (3.7)
# Requirement already satisfied: ipykernel==6.29.4 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 17)) (6.29.4)
# Requirement already satisfied: ipython==8.24.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 18)) (8.24.0)
# Requirement already satisfied: jedi==0.19.1 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 19)) (0.19.1)
# Requirement already satisfied: joblib==1.4.2 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 20)) (1.4.2)
# Requirement already satisfied: jupyter_client==8.6.2 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 21)) (8.6.2)
# Requirement already satisfied: jupyter_core==5.7.2 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 22)) (5.7.2)
# Requirement already satisfied: keras==3.3.3 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 23)) (3.3.3)
# Requirement already satisfied: libclang==18.1.1 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 24)) (18.1.1)
# Requirement already satisfied: Markdown==3.6 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 25)) (3.6)
# Requirement already satisfied: markdown-it-py==3.0.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 26)) (3.0.0)
# Requirement already satisfied: MarkupSafe==2.1.5 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 27)) (2.1.5)
# Requirement already satisfied: matplotlib-inline==0.1.7 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 28)) (0.1.7)
# Requirement already satisfied: mdurl==0.1.2 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 29)) (0.1.2)
# Requirement already satisfied: ml-dtypes==0.3.2 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 30)) (0.3.2)
# Requirement already satisfied: namex==0.0.8 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 31)) (0.0.8)
# Requirement already satisfied: nest-asyncio==1.6.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 32)) (1.6.0)
# Requirement already satisfied: numpy==1.26.4 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 33)) (1.26.4)
# Requirement already satisfied: opt-einsum==3.3.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 34)) (3.3.0)
# Requirement already satisfied: optree==0.11.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 35)) (0.11.0)
# Requirement already satisfied: packaging==24.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 36)) (24.0)
# Requirement already satisfied: pandas==2.2.2 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 37)) (2.2.2)
# Requirement already satisfied: parso==0.8.4 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 38)) (0.8.4)
# Requirement already satisfied: pexpect==4.9.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 39)) (4.9.0)
# Requirement already satisfied: platformdirs==4.2.2 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 40)) (4.2.2)
# Requirement already satisfied: prompt-toolkit==3.0.43 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 41)) (3.0.43)
# Requirement already satisfied: protobuf==4.25.3 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 42)) (4.25.3)
# Requirement already satisfied: psutil==5.9.8 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 43)) (5.9.8)
# Requirement already satisfied: ptyprocess==0.7.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 44)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 45)) (0.2.2)
# Requirement already satisfied: Pygments==2.18.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 46)) (2.18.0)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 47)) (2.9.0.post0)
# Requirement already satisfied: pytz==2024.1 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 48)) (2024.1)
# Requirement already satisfied: pyzmq==26.0.3 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 49)) (26.0.3)
# Requirement already satisfied: requests==2.32.2 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 50)) (2.32.2)
# Requirement already satisfied: rich==13.7.1 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 51)) (13.7.1)
# Requirement already satisfied: scikit-learn==1.5.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 52)) (1.5.0)
# Requirement already satisfied: scipy==1.13.1 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 53)) (1.13.1)
# Requirement already satisfied: six==1.16.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 54)) (1.16.0)
# Requirement already satisfied: stack-data==0.6.3 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 55)) (0.6.3)
# Requirement already satisfied: tensorboard==2.16.2 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 56)) (2.16.2)
# Requirement already satisfied: tensorboard-data-server==0.7.2 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 57)) (0.7.2)
# Requirement already satisfied: tensorflow==2.16.1 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 58)) (2.16.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.37.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 59)) (0.37.0)
# Requirement already satisfied: termcolor==2.4.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 60)) (2.4.0)
# Requirement already satisfied: threadpoolctl==3.5.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 61)) (3.5.0)
# Requirement already satisfied: tornado==6.4 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 62)) (6.4)
# Requirement already satisfied: traitlets==5.14.3 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 63)) (5.14.3)
# Requirement already satisfied: typing_extensions==4.12.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 64)) (4.12.0)
# Requirement already satisfied: tzdata==2024.1 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 65)) (2024.1)
# Requirement already satisfied: urllib3==2.2.1 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 66)) (2.2.1)
# Requirement already satisfied: wcwidth==0.2.13 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 67)) (0.2.13)
# Requirement already satisfied: Werkzeug==3.0.3 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 68)) (3.0.3)
# Requirement already satisfied: wrapt==1.16.0 in ./venv/lib/python3.11/site-packages (from -r requirements.txt (line 69)) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./venv/lib/python3.11/site-packages (from astunparse==1.6.3->-r requirements.txt (line 4)) (0.43.0)
# Requirement already satisfied: setuptools>=41.0.0 in ./venv/lib/python3.11/site-packages (from tensorboard==2.16.2->-r requirements.txt (line 56)) (65.5.0)
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing all the requirements. 
import numpy as np
import pandas as pd
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, precision_score, accuracy_score, recall_score, f1_score, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
# Out:
# 2024-05-26 22:11:16.494295: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
final_results_table = pd.DataFrame(columns=['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score'])

# %% [markdown]
# ### Algorithm 1: Artificial Neural Networks

# %%
# Load data from a CSV file
df = pd.read_csv('baba_stock_data.csv')

# Ensure 'Date' column is in datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')

# Sorting data by date
df = df.sort_values(by='Date')

# Calculate the daily movement (1 for up, 0 for down)
df['Movement'] = (df['Close'].diff() > 0).astype(int)

# Remove the first row with NaN value due to diff()
df = df.dropna()

# Feature selection
features = ['Open', 'High', 'Low', 'Close', 'Adj Close']
X = df[features]
y = df['Movement']

# training-testing ratios
ratios = [0.4,0.3,0.2,0.1] 

results = {}

for ratio in ratios:

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=ratio, random_state=0)

    # Standardize the features
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # Initialize the ANN
    model = Sequential()
    model.add(Dense(units=64, activation='relu', input_dim=X_train.shape[1]))
    model.add(Dense(units=32, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))

    # Compile the ANN
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # Train the ANN
    model.fit(X_train, y_train, epochs=50, batch_size=10, verbose=1)

    # Predictions
    y_pred = model.predict(X_test)
    y_pred = (y_pred > 0.5).astype(int)

    # Confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    print(f"Confusion Matrix for split {ratio}:\n", cm)

    # Accuracy, Precision, Recall, F1-score
    accuracy_q = accuracy_score(y_test, y_pred)
    precision_q = precision_score(y_test, y_pred)
    recall_q = recall_score(y_test, y_pred)
    f1_q = f1_score(y_test, y_pred)

    results[ratio] = {'precision': precision_q, 'accuracy': accuracy_q, 'recall': recall_q, 'f1': f1_q}

# Detailed classification report
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Get the most recent data point and format it as a DataFrame
last_data_point = df[features].iloc[-1].to_frame().T

# Standardize the last data point
last_data_point_scaled = scaler.transform(last_data_point)

# Predict the movement for the next day
predicted_movement = model.predict(last_data_point_scaled)
predicted_movement = (predicted_movement > 0.5).astype(int)

# Interpret the result
movement_label = "Up" if predicted_movement[0][0] == 1 else "Down"
print(f'The predicted movement for the next trading day is: {movement_label}')

# Print results
print("Results:")
print("Ratio Precision Accuracy Recall F1")
for ratio, metrics in results.items():
    print(f"{ratio:}\t{metrics['precision']:.4f}\t{metrics['accuracy']:.4f}\t{metrics['recall']:.4f}\t{metrics['f1']:.4f}")
print("Average F1",round(sum([ results[ratio]['f1'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Accuracy",round(sum([ results[ratio]['accuracy'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Precision",round(sum([ results[ratio]['precision'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Recall",round(sum([ results[ratio]['recall'] for ratio in results.keys() ])/len(results.keys()),4))

final_results_table.loc[len(final_results_table)] = ['ANN', 
                                                     round(sum([ results[ratio]['accuracy'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['precision'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['recall'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['f1'] for ratio in results.keys() ])/len(results.keys()),4)
                                                    ]
# Out:
# /Users/afnan/Downloads/Code Files (.py)/venv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6281 - loss: 0.6826
# Epoch 2/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5915 - loss: 0.6886
# Epoch 3/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5789 - loss: 0.6840
# Epoch 4/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5810 - loss: 0.6788
# Epoch 5/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6472 - loss: 0.6647
# Epoch 6/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6446 - loss: 0.6531
# Epoch 7/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6355 - loss: 0.6621
# Epoch 8/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6295 - loss: 0.6529
# Epoch 9/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6660 - loss: 0.6489
# Epoch 10/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6111 - loss: 0.6530
# Epoch 11/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6418 - loss: 0.6344
# Epoch 12/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6303 - loss: 0.6404
# Epoch 13/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6891 - loss: 0.6176
# Epoch 14/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6375 - loss: 0.6333
# Epoch 15/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6833 - loss: 0.6195
# Epoch 16/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6936 - loss: 0.6307
# Epoch 17/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6209 - loss: 0.6163
# Epoch 18/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6570 - loss: 0.6133
# Epoch 19/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6878 - loss: 0.6051
# Epoch 20/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6166 - loss: 0.6434
# Epoch 21/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7323 - loss: 0.5796
# Epoch 22/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6799 - loss: 0.5810
# Epoch 23/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7121 - loss: 0.5831
# Epoch 24/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6703 - loss: 0.5993
# Epoch 25/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6990 - loss: 0.5705
# Epoch 26/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6830 - loss: 0.5859
# Epoch 27/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7008 - loss: 0.5819
# Epoch 28/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7390 - loss: 0.5699
# Epoch 29/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7723 - loss: 0.5440
# Epoch 30/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6902 - loss: 0.5764
# Epoch 31/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6733 - loss: 0.5910
# Epoch 32/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6984 - loss: 0.5739
# Epoch 33/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6961 - loss: 0.5807
# Epoch 34/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7317 - loss: 0.5602
# Epoch 35/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6853 - loss: 0.5825
# Epoch 36/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7026 - loss: 0.5873
# Epoch 37/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6654 - loss: 0.6096
# Epoch 38/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7252 - loss: 0.5669
# Epoch 39/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7155 - loss: 0.5869
# Epoch 40/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7458 - loss: 0.5492
# Epoch 41/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7442 - loss: 0.5626
# Epoch 42/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6985 - loss: 0.5811
# Epoch 43/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6919 - loss: 0.5620
# Epoch 44/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7055 - loss: 0.5778
# Epoch 45/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7141 - loss: 0.5745
# Epoch 46/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7064 - loss: 0.5930
# Epoch 47/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7063 - loss: 0.5766
# Epoch 48/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6987 - loss: 0.5809
# Epoch 49/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6932 - loss: 0.5500
# Epoch 50/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6993 - loss: 0.5683
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Confusion Matrix for split 0.4:
#  [[83 34]
#  [36 84]]
# /Users/afnan/Downloads/Code Files (.py)/venv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4868 - loss: 0.6951
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5766 - loss: 0.6877
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5450 - loss: 0.6882
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5505 - loss: 0.6839
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5948 - loss: 0.6762
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5843 - loss: 0.6759
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5886 - loss: 0.6683
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5771 - loss: 0.6687
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5963 - loss: 0.6659
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6463 - loss: 0.6497
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6135 - loss: 0.6485
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6087 - loss: 0.6522
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6333 - loss: 0.6485
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5775 - loss: 0.6577
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6707 - loss: 0.6245
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6722 - loss: 0.6019
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6659 - loss: 0.6142
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6556 - loss: 0.6179
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6741 - loss: 0.6203
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6712 - loss: 0.5966
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6373 - loss: 0.6332
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6836 - loss: 0.5997
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6955 - loss: 0.5927
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6479 - loss: 0.6082
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6767 - loss: 0.5949
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6492 - loss: 0.6096
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6719 - loss: 0.6073
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6662 - loss: 0.6189
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6979 - loss: 0.5911
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7265 - loss: 0.5753
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7019 - loss: 0.6025
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6715 - loss: 0.5890
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6897 - loss: 0.5949
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6922 - loss: 0.5804
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6897 - loss: 0.5933
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7070 - loss: 0.5754
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7219 - loss: 0.5718
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7141 - loss: 0.5637
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6659 - loss: 0.6106
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7093 - loss: 0.5801
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7303 - loss: 0.5729
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6982 - loss: 0.6016
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7030 - loss: 0.5727
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7045 - loss: 0.5793
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7371 - loss: 0.5761
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6722 - loss: 0.6160
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7509 - loss: 0.5454
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6890 - loss: 0.5852
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7542 - loss: 0.5353
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7000 - loss: 0.5775
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Confusion Matrix for split 0.3:
#  [[72 18]
#  [29 59]]
# Epoch 1/50
# /Users/afnan/Downloads/Code Files (.py)/venv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5673 - loss: 0.6886
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6207 - loss: 0.6807
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6180 - loss: 0.6750
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6449 - loss: 0.6490
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6505 - loss: 0.6445
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6493 - loss: 0.6353
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6607 - loss: 0.6248
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6729 - loss: 0.6140
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6403 - loss: 0.6098
# Epoch 10/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6760 - loss: 0.5949
# Epoch 11/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6631 - loss: 0.6179
# Epoch 12/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6603 - loss: 0.5975
# Epoch 13/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6938 - loss: 0.5965
# Epoch 14/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7389 - loss: 0.5721
# Epoch 15/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6872 - loss: 0.5963
# Epoch 16/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6776 - loss: 0.5837
# Epoch 17/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7107 - loss: 0.5844
# Epoch 18/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7159 - loss: 0.5690
# Epoch 19/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7049 - loss: 0.5655
# Epoch 20/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6722 - loss: 0.5783
# Epoch 21/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7129 - loss: 0.5666
# Epoch 22/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6899 - loss: 0.5769
# Epoch 23/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6889 - loss: 0.5911
# Epoch 24/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6835 - loss: 0.6011
# Epoch 25/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7016 - loss: 0.5726
# Epoch 26/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7438 - loss: 0.5501
# Epoch 27/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6921 - loss: 0.5858
# Epoch 28/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7335 - loss: 0.5641
# Epoch 29/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6622 - loss: 0.5977
# Epoch 30/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6576 - loss: 0.6110
# Epoch 31/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7109 - loss: 0.5814
# Epoch 32/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7336 - loss: 0.5531
# Epoch 33/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7235 - loss: 0.5696
# Epoch 34/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7317 - loss: 0.5551
# Epoch 35/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7496 - loss: 0.5499
# Epoch 36/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6780 - loss: 0.5815
# Epoch 37/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6867 - loss: 0.6078
# Epoch 38/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7084 - loss: 0.6018
# Epoch 39/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7197 - loss: 0.5751
# Epoch 40/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6964 - loss: 0.5803
# Epoch 41/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7147 - loss: 0.5622
# Epoch 42/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7265 - loss: 0.5612
# Epoch 43/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7059 - loss: 0.5774
# Epoch 44/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6468 - loss: 0.6087
# Epoch 45/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7053 - loss: 0.5479
# Epoch 46/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6785 - loss: 0.5881
# Epoch 47/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7191 - loss: 0.5689
# Epoch 48/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7242 - loss: 0.5531
# Epoch 49/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7283 - loss: 0.5677
# Epoch 50/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7514 - loss: 0.5636
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x139205260> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/stepWARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x139205260> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Confusion Matrix for split 0.2:
#  [[51 13]
#  [14 41]]
# /Users/afnan/Downloads/Code Files (.py)/venv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4879 - loss: 0.6989
# Epoch 2/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5838 - loss: 0.6794
# Epoch 3/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5682 - loss: 0.6885
# Epoch 4/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5598 - loss: 0.6854
# Epoch 5/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5996 - loss: 0.6750
# Epoch 6/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6117 - loss: 0.6649
# Epoch 7/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6463 - loss: 0.6540
# Epoch 8/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6065 - loss: 0.6605
# Epoch 9/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5973 - loss: 0.6554
# Epoch 10/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6246 - loss: 0.6412
# Epoch 11/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6541 - loss: 0.6280
# Epoch 12/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6645 - loss: 0.6236
# Epoch 13/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6493 - loss: 0.6307
# Epoch 14/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6798 - loss: 0.6229
# Epoch 15/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6255 - loss: 0.6248
# Epoch 16/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7093 - loss: 0.6104
# Epoch 17/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6014 - loss: 0.6398
# Epoch 18/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6542 - loss: 0.6197
# Epoch 19/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6894 - loss: 0.6077
# Epoch 20/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6411 - loss: 0.6418
# Epoch 21/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7036 - loss: 0.5893
# Epoch 22/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6816 - loss: 0.6018
# Epoch 23/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6772 - loss: 0.6099
# Epoch 24/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6940 - loss: 0.5972
# Epoch 25/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6818 - loss: 0.6105
# Epoch 26/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6913 - loss: 0.6054
# Epoch 27/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6642 - loss: 0.6123
# Epoch 28/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7028 - loss: 0.5850
# Epoch 29/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6587 - loss: 0.5995
# Epoch 30/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7146 - loss: 0.5769
# Epoch 31/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6860 - loss: 0.6007
# Epoch 32/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6808 - loss: 0.5932
# Epoch 33/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7122 - loss: 0.5794
# Epoch 34/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6832 - loss: 0.6006
# Epoch 35/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7176 - loss: 0.6019
# Epoch 36/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6802 - loss: 0.5956
# Epoch 37/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6517 - loss: 0.6048
# Epoch 38/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6909 - loss: 0.5875
# Epoch 39/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6677 - loss: 0.5963
# Epoch 40/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6826 - loss: 0.6030
# Epoch 41/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6644 - loss: 0.6251
# Epoch 42/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6652 - loss: 0.6203
# Epoch 43/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6878 - loss: 0.5979
# Epoch 44/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7018 - loss: 0.5911
# Epoch 45/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6673 - loss: 0.5973
# Epoch 46/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7145 - loss: 0.6038
# Epoch 47/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6532 - loss: 0.6127
# Epoch 48/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6836 - loss: 0.5742
# Epoch 49/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6870 - loss: 0.5931
# Epoch 50/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7042 - loss: 0.5836
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Confusion Matrix for split 0.1:
#  [[27  3]
#  [ 4 26]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89        30
#            1       0.90      0.87      0.88        30
#
#     accuracy                           0.88        60
#    macro avg       0.88      0.88      0.88        60
# weighted avg       0.88      0.88      0.88        60
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# The predicted movement for the next trading day is: Up
# Results:
# Ratio Precision Accuracy Recall F1
# 0.4	0.7119	0.7046	0.7000	0.7059
# 0.3	0.7662	0.7360	0.6705	0.7152
# 0.2	0.7593	0.7731	0.7455	0.7523
# 0.1	0.8966	0.8833	0.8667	0.8814
# Average F1 0.7637
# Average Accuracy 0.7743
# Average Precision 0.7835
# Average Recall 0.7456

# %% [markdown]
# ### Algorithm 2: K-Nearest Neighbors

# %%
# Load data from a CSV file
df = pd.read_csv('baba_stock_data.csv')

# Ensure 'Date' column is in datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')

# Sorting data by date
df = df.sort_values(by='Date')

# Calculate the daily movement (1 for up, 0 for down)
df['Movement'] = (df['Close'].diff() > 0).astype(int)

# Remove the first row with NaN value due to diff()
df = df.dropna()

# Feature selection
features = ['Open', 'High', 'Low', 'Close', 'Adj Close']
X = df[features]
y = df['Movement']

# training-testing ratios
ratios = [0.4,0.3,0.2,0.1] 

results = {}

for ratio in ratios:

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=ratio, random_state=0)

    # Standardize the features
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # Initialize and train the KNN classifier
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(X_train, y_train)

    # Make predictions
    y_pred = knn.predict(X_test)

    # Evaluate the model
    print(f"Confusion Matrix for ratio {ratio}:")
    print(confusion_matrix(y_test, y_pred))

    # Calculate metrics
    precision_q = precision_score(y_test, y_pred)
    accuracy_q = accuracy_score(y_test, y_pred)
    recall_q = recall_score(y_test, y_pred)
    f1_q = f1_score(y_test, y_pred)
    
    results[ratio] = {'precision': precision_q, 'accuracy': accuracy_q, 'recall': recall_q, 'f1': f1_q}

# Print results
print("Results:")
print("Ratio Precision Accuracy Recall F1")
for ratio, metrics in results.items():
    print(f"{ratio:}\t{metrics['precision']:.4f}\t{metrics['accuracy']:.4f}\t{metrics['recall']:.4f}\t{metrics['f1']:.4f}")
print("Average F1",round(sum([ results[ratio]['f1'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Accuracy",round(sum([ results[ratio]['accuracy'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Precision",round(sum([ results[ratio]['precision'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Recall",round(sum([ results[ratio]['recall'] for ratio in results.keys() ])/len(results.keys()),4))

final_results_table.loc[len(final_results_table)] = ['KNN', 
                                                     round(sum([ results[ratio]['accuracy'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['precision'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['recall'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['f1'] for ratio in results.keys() ])/len(results.keys()),4)
                                                    ]
# Out:
# Confusion Matrix for ratio 0.4:
# [[84 33]
#  [66 54]]
# Confusion Matrix for ratio 0.3:
# [[59 31]
#  [45 43]]
# Confusion Matrix for ratio 0.2:
# [[44 20]
#  [31 24]]
# Confusion Matrix for ratio 0.1:
# [[24  6]
#  [15 15]]
# Results:
# Ratio Precision Accuracy Recall F1
# 0.4	0.6207	0.5823	0.4500	0.5217
# 0.3	0.5811	0.5730	0.4886	0.5309
# 0.2	0.5455	0.5714	0.4364	0.4848
# 0.1	0.7143	0.6500	0.5000	0.5882
# Average F1 0.5314
# Average Accuracy 0.5942
# Average Precision 0.6154
# Average Recall 0.4688

# %% [markdown]
# ### Algorithm 3: Decision Trees

# %%
# Load data from a CSV file
df = pd.read_csv('baba_stock_data.csv')

# Ensure 'Date' column is in datetime format (if not already)
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')

# Sorting data by date
df = df.sort_values(by='Date')

# Calculate the daily movement (1 for up, 0 for down)
df['Movement'] = (df['Close'].diff() > 0).astype(int)

# Remove the first row with NaN value due to diff()
df = df.dropna()

# Feature selection
features = ['Open', 'High', 'Low', 'Close', 'Adj Close']
X = df[features]
y = df['Movement']

# training-testing ratios
ratios = [0.4,0.3,0.2,0.1] 

results = {}

for ratio in ratios:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=ratio, random_state=0)


    # Model training
    classifier = DecisionTreeClassifier(criterion='entropy', random_state=0)
    classifier.fit(X_train, y_train)

    # Predictions
    y_pred = classifier.predict(X_test)

    # Confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    print(f"Confusion Matrix for ratio {ratio}:\n", cm)

    # Calculate metrics
    precision_q = precision_score(y_test, y_pred)
    accuracy_q = accuracy_score(y_test, y_pred)
    recall_q = recall_score(y_test, y_pred)
    f1_q = f1_score(y_test, y_pred)
    
    results[ratio] = {'precision': precision_q, 'accuracy': accuracy_q, 'recall': recall_q, 'f1': f1_q}


# Detailed classification report
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Get the most recent data point and format it as a DataFrame
last_data_point = df[features].iloc[-1].to_frame().T

# Predict the movement for the next day
predicted_movement = classifier.predict(last_data_point)

# Interpret the result
movement_label = "Up" if predicted_movement[0] == 1 else "Down"
print(f'The predicted movement for the next trading day is: {movement_label}')

# Print results
print("Results:")
print("Ratio Precision Accuracy Recall F1")
for ratio, metrics in results.items():
    print(f"{ratio:}\t{metrics['precision']:.4f}\t{metrics['accuracy']:.4f}\t{metrics['recall']:.4f}\t{metrics['f1']:.4f}")
print("Average F1",round(sum([ results[ratio]['f1'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Accuracy",round(sum([ results[ratio]['accuracy'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Precision",round(sum([ results[ratio]['precision'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Recall",round(sum([ results[ratio]['recall'] for ratio in results.keys() ])/len(results.keys()),4))

final_results_table.loc[len(final_results_table)] = ['Decision Tree', 
                                                     round(sum([ results[ratio]['accuracy'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['precision'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['recall'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['f1'] for ratio in results.keys() ])/len(results.keys()),4)
                                                    ]
# Out:
# Confusion Matrix for ratio 0.4:
#  [[79 38]
#  [54 66]]
# Confusion Matrix for ratio 0.3:
#  [[61 29]
#  [42 46]]
# Confusion Matrix for ratio 0.2:
#  [[43 21]
#  [25 30]]
# Confusion Matrix for ratio 0.1:
#  [[23  7]
#  [11 19]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.77      0.72        30
#            1       0.73      0.63      0.68        30
#
#     accuracy                           0.70        60
#    macro avg       0.70      0.70      0.70        60
# weighted avg       0.70      0.70      0.70        60
#
# The predicted movement for the next trading day is: Up
# Results:
# Ratio Precision Accuracy Recall F1
# 0.4	0.6346	0.6118	0.5500	0.5893
# 0.3	0.6133	0.6011	0.5227	0.5644
# 0.2	0.5882	0.6134	0.5455	0.5660
# 0.1	0.7308	0.7000	0.6333	0.6786
# Average F1 0.5996
# Average Accuracy 0.6316
# Average Precision 0.6417
# Average Recall 0.5629

# %% [markdown]
# ### Algorithm 4: Random Forest

# %%
# Load data from a CSV file
df = pd.read_csv('baba_stock_data.csv')

# Ensure 'Date' column is in datetime format (if not already)
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')

# Sorting data by date
df = df.sort_values(by='Date')

# Calculate the daily movement (1 for up, 0 for down)
df['Movement'] = (df['Close'].diff() > 0).astype(int)

# Remove the first row with NaN value due to diff()
df = df.dropna()

# Feature selection
features = ['Open', 'High', 'Low', 'Close', 'Adj Close']
X = df[features]
y = df['Movement']

# training-testing ratios
ratios = [0.4,0.3,0.2,0.1] 

results = {}

for ratio in ratios:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=ratio, random_state=0)

    # Model training
    classifier = RandomForestClassifier(n_estimators=100, criterion='entropy', random_state=0)
    classifier.fit(X_train, y_train)

    # Predictions
    y_pred = classifier.predict(X_test)

    # Confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    print(f"Confusion Matrix for ratio {ratio}:\n", cm)

    # Calculate metrics
    precision_q = precision_score(y_test, y_pred)
    accuracy_q = accuracy_score(y_test, y_pred)
    recall_q = recall_score(y_test, y_pred)
    f1_q = f1_score(y_test, y_pred)
    
    results[ratio] = {'precision': precision_q, 'accuracy': accuracy_q, 'recall': recall_q, 'f1': f1_q}


# Detailed classification report
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Get the most recent data point and format it as a DataFrame
last_data_point = df[features].iloc[-1].to_frame().T

# Predict the movement for the next day
predicted_movement = classifier.predict(last_data_point)

# Interpret the result
movement_label = "Up" if predicted_movement[0] == 1 else "Down"
print(f'The predicted movement for the next trading day is: {movement_label}')

# Print results
print("Results:")
print("Ratio Precision Accuracy Recall F1")
for ratio, metrics in results.items():
    print(f"{ratio:}\t{metrics['precision']:.4f}\t{metrics['accuracy']:.4f}\t{metrics['recall']:.4f}\t{metrics['f1']:.4f}")
print("Average F1",round(sum([ results[ratio]['f1'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Accuracy",round(sum([ results[ratio]['accuracy'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Precision",round(sum([ results[ratio]['precision'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Recall",round(sum([ results[ratio]['recall'] for ratio in results.keys() ])/len(results.keys()),4))

final_results_table.loc[len(final_results_table)] = ['Random Forest', 
                                                     round(sum([ results[ratio]['accuracy'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['precision'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['recall'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['f1'] for ratio in results.keys() ])/len(results.keys()),4)
                                                    ]
# Out:
# Confusion Matrix for ratio 0.4:
#  [[85 32]
#  [60 60]]
# Confusion Matrix for ratio 0.3:
#  [[62 28]
#  [41 47]]
# Confusion Matrix for ratio 0.2:
#  [[40 24]
#  [27 28]]
# Confusion Matrix for ratio 0.1:
#  [[25  5]
#  [13 17]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.83      0.74        30
#            1       0.77      0.57      0.65        30
#
#     accuracy                           0.70        60
#    macro avg       0.72      0.70      0.69        60
# weighted avg       0.72      0.70      0.69        60
#
# The predicted movement for the next trading day is: Up
# Results:
# Ratio Precision Accuracy Recall F1
# 0.4	0.6522	0.6118	0.5000	0.5660
# 0.3	0.6267	0.6124	0.5341	0.5767
# 0.2	0.5385	0.5714	0.5091	0.5234
# 0.1	0.7727	0.7000	0.5667	0.6538
# Average F1 0.58
# Average Accuracy 0.6239
# Average Precision 0.6475
# Average Recall 0.5275

# %% [markdown]
# ### Algorithm 5: Support Vector Machines

# %%
# Load data from a CSV file
df = pd.read_csv('baba_stock_data.csv')

# Ensure ’Date’ column is in datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')

# Sorting data by date
df = df.sort_values(by='Date')

# Calculate the daily movement (1 for up, 0 for down)
df['Movement'] = (df['Close'].diff() > 0).astype(int)

# Remove the first row with NaN value due to diff()
df = df.dropna()

# Feature selection
features = ['Open', 'High', 'Low', 'Close', 'Adj Close']
X = df[features]
y = df['Movement']

# training-testing ratios
ratios = [0.4,0.3,0.2,0.1] 

results = {}

for ratio in ratios:
    X_train, X_test, y_train, y_test =train_test_split(X,y,test_size=ratio,random_state=0)


    # Standardize the features
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # Initialize and train the SVM classifier
    svm_classifier = SVC(kernel='linear', random_state=0)
    svm_classifier.fit(X_train, y_train)

    # Predictions
    y_pred = svm_classifier.predict(X_test)

    # Confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    print(f"Confusion Matrix for ratio {ratio}:\n", cm)

    # Calculate metrics
    precision_q = precision_score(y_test, y_pred)
    accuracy_q = accuracy_score(y_test, y_pred)
    recall_q = recall_score(y_test, y_pred)
    f1_q = f1_score(y_test, y_pred)
    
    results[ratio] = {'precision': precision_q, 'accuracy': accuracy_q, 'recall': recall_q, 'f1': f1_q}


# Detailed classification report
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Get the most recent data point and format it as a DataFrame
last_data_point = df[features].iloc[-1].to_frame().T

# Standardize the last data point
last_data_point_scaled = scaler.transform(last_data_point)

# Predict the movement for the next day
predicted_movement = svm_classifier.predict(last_data_point_scaled)

# Interpret the result
movement_label = "Up" if predicted_movement[0] == 1 else "Down"
print(f'The predicted movement for the next trading day is:{movement_label}')

# Print results
print("Results:")
print("Ratio Precision Accuracy Recall F1")
for ratio, metrics in results.items():
    print(f"{ratio:}\t{metrics['precision']:.4f}\t{metrics['accuracy']:.4f}\t{metrics['recall']:.4f}\t{metrics['f1']:.4f}")
print("Average F1",round(sum([ results[ratio]['f1'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Accuracy",round(sum([ results[ratio]['accuracy'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Precision",round(sum([ results[ratio]['precision'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Recall",round(sum([ results[ratio]['recall'] for ratio in results.keys() ])/len(results.keys()),4))

final_results_table.loc[len(final_results_table)] = ['SVM',
                                                     round(sum([ results[ratio]['accuracy'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['precision'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['recall'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['f1'] for ratio in results.keys() ])/len(results.keys()),4)
                                                    ]
# Out:
# Confusion Matrix for ratio 0.4:
#  [[110   7]
#  [ 85  35]]
# Confusion Matrix for ratio 0.3:
#  [[85  5]
#  [62 26]]
# Confusion Matrix for ratio 0.2:
#  [[60  4]
#  [33 22]]
# Confusion Matrix for ratio 0.1:
#  [[27  3]
#  [14 16]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.90      0.76        30
#            1       0.84      0.53      0.65        30
#
#     accuracy                           0.72        60
#    macro avg       0.75      0.72      0.71        60
# weighted avg       0.75      0.72      0.71        60
#
# The predicted movement for the next trading day is:Down
# Results:
# Ratio Precision Accuracy Recall F1
# 0.4	0.8333	0.6118	0.2917	0.4321
# 0.3	0.8387	0.6236	0.2955	0.4370
# 0.2	0.8462	0.6891	0.4000	0.5432
# 0.1	0.8421	0.7167	0.5333	0.6531
# Average F1 0.5163
# Average Accuracy 0.6603
# Average Precision 0.8401
# Average Recall 0.3801

# %% [markdown]
# ### Algorithm 6: Reinforcement Learning (Q-learning)

# %%
# Seed for reproducibility
random.seed(42)

# Loading our stock dataset
file_path = 'baba_stock_data.csv'
data = pd.read_csv(file_path)

# Convert Date to datetime to sort by date
data['Date'] = pd.to_datetime(data['Date'],format='%d-%m-%Y')
data = data.sort_values('Date')

# Feature engineering - creating a new target variable `Profitable` (0/1) based on if the stock price increased or decreased on that day
data['Profitable'] = (data['Close'] > data['Open']).astype(int)

# Select relevant features (excluding 'Adj Close')
X = data[['Open', 'High', 'Low', 'Close', 'Volume']]
y = data['Profitable']
dates = data['Date']

# Reinforcement Learning (Q-learning)
def q_learning_train(X, y, episodes=1000, learning_rate=0.1, discount_factor=0.95, epsilon=0.1):
    n_actions = 2  # Buy or Sell (0 or 1)
    n_states = X.shape[0]
    
    # Initialize Q-table with zeros
    Q = np.zeros((n_states, n_actions))
    
    for _ in range(episodes):
        state = random.randint(0, n_states - 1)
        while True:
            if random.uniform(0, 1) < epsilon: # epsilon is our exploration rate
                action = random.randint(0, n_actions - 1)  # Explore
            else:
                action = np.argmax(Q[state, :])  # Exploit
            
            reward = y.iloc[state] if action == 1 else -y.iloc[state]
            
            next_state = (state + 1) % n_states
            Q[state, action] = Q[state, action] + learning_rate * (reward + discount_factor * np.max(Q[next_state, :]) - Q[state, action])
            
            state = next_state
            if state == 0:
                break
    
    return Q

def q_learning_predict(Q, X):
    '''Predicts the actions for each state in X (test data) using the Q-table.'''
    y_pred = []
    for state in range(X.shape[0]):
        action = np.argmax(Q[state, :])
        y_pred.append(action)
    return np.array(y_pred)

def print_confusion_matrix(cm, title):
    print(f"{title}")
    print(cm,end='\n\n')


# training-testing ratios
ratios = [0.4,0.3,0.2,0.1] 

results = {}

for ratio in ratios:

    # Split the dataset
    X_train, X_test, y_train, y_test, dates_train, dates_test = train_test_split(X, y, dates, test_size=ratio, random_state=42)

    # Standardize the features
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # Train Q-learning model
    Q = q_learning_train(pd.DataFrame(X_train), y_train)
    y_pred_q = q_learning_predict(Q, pd.DataFrame(X_test))

    # Print confusion matrix
    cm = confusion_matrix(y_test, y_pred_q)
    print_confusion_matrix(cm, f"Confusion Matrix for ratio {ratio}")

    # Calculate metrics
    precision_q = precision_score(y_test, y_pred_q)
    accuracy_q = accuracy_score(y_test, y_pred_q)
    recall_q = recall_score(y_test, y_pred_q)
    f1_q = f1_score(y_test, y_pred_q)
    
    results[ratio] = {'precision': precision_q, 'accuracy': accuracy_q, 'recall': recall_q, 'f1': f1_q}

# Print results
print("Results:")
print("Ratio Precision Accuracy Recall F1")
for ratio, metrics in results.items():
    print(f"{ratio:}\t{metrics['precision']:.4f}\t{metrics['accuracy']:.4f}\t{metrics['recall']:.4f}\t{metrics['f1']:.4f}")
print("Average F1",round(sum([ results[ratio]['f1'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Accuracy",round(sum([ results[ratio]['accuracy'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Precision",round(sum([ results[ratio]['precision'] for ratio in results.keys() ])/len(results.keys()),4))
print("Average Recall",round(sum([ results[ratio]['recall'] for ratio in results.keys() ])/len(results.keys()),4))

final_results_table.loc[len(final_results_table)] = ['RL/Q-Learning', 
                                                     round(sum([ results[ratio]['accuracy'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['precision'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['recall'] for ratio in results.keys() ])/len(results.keys()),4),
                                                     round(sum([ results[ratio]['f1'] for ratio in results.keys() ])/len(results.keys()),4)
                                                    ]
# Out:
# Confusion Matrix for ratio 0.4
# [[42 59]
#  [69 67]]
#
# Confusion Matrix for ratio 0.3
# [[29 47]
#  [40 62]]
#
# Confusion Matrix for ratio 0.2
# [[17 32]
#  [28 42]]
#
# Confusion Matrix for ratio 0.1
# [[11 10]
#  [12 27]]
#
# Results:
# Ratio Precision Accuracy Recall F1
# 0.4	0.5317	0.4599	0.4926	0.5115
# 0.3	0.5688	0.5112	0.6078	0.5877
# 0.2	0.5676	0.4958	0.6000	0.5833
# 0.1	0.7297	0.6333	0.6923	0.7105
# Average F1 0.5982
# Average Accuracy 0.5251
# Average Precision 0.5995
# Average Recall 0.5982

# %% [markdown]
# ### Our final comparison table tabulating our results

# %%
final_results_table
# Out:
#            Model  Accuracy  Precision  Recall  F1 Score
# 0            ANN    0.7743     0.7835  0.7456    0.7637
# 1            KNN    0.5942     0.6154  0.4688    0.5314
# 2  Decision Tree    0.6316     0.6417  0.5629    0.5996
# 3  Random Forest    0.6239     0.6475  0.5275    0.5800
# 4            SVM    0.6603     0.8401  0.3801    0.5163
# 5  RL/Q-Learning    0.5251     0.5995  0.5982    0.5982
